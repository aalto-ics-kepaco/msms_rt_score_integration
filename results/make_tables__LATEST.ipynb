# %% [markdown]
# # Tables presented in the Publication
#
# *Probabilistic Framework for Integration of Mass Spectrum and Retention Time Information in Metabolite Identification*
#
# by: Eric Bach, Simon Rogers, John Williamson and Juho Rousu, 2020

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
result_version = "LATEST"

# %% [markdown]
# ## Main Document
#
# ### Table Comparing the different MS+RT Score Intergration Methods
#
# We compare performance of the different MS+RT score integration frameworks in **Table 2**.

# %%
from msmsrt_scorer.experiments.figures_and_tables import table__alternative_methods_comparison

res_global_score, res_global_sigf = table__alternative_methods_comparison(result_version)
res_global_score

# print(table__alternative_methods_comparison("..", test="wilcoxon_oneside", to_latex=True))
# Out:
#                                                      Top-1       Top-5  \
# Dataset       Ionization Method
# EA (Massbank) positive   MS + RT (Chain-graph)  23.9 (***)        59.2
#                          MS + RT (MetFrag 2.2)  24.0 (***)        59.0
#                          MS + RT (our)          27.3 (***)  61.6 (***)
#                          Only MS                      21.2        59.0
#               negative   MS + RT (Chain-graph)  27.2 (***)  59.5 (***)
#                          MS + RT (MetFrag 2.2)  30.2 (***)  59.2 (***)
#                          MS + RT (our)          28.7 (***)  61.9 (***)
#                          Only MS                      22.8        57.6
# CASMI 2016    positive   MS + RT (Chain-graph)        11.9        36.5
#                          MS + RT (MetFrag 2.2)  13.7 (***)        36.2
#                          MS + RT (our)          14.0 (***)  40.7 (***)
#                          Only MS                      11.8        37.3
#               negative   MS + RT (Chain-graph)  13.2 (***)  49.4 (***)
#                          MS + RT (MetFrag 2.2)  14.0 (***)        42.0
#                          MS + RT (our)          15.2 (***)  47.2 (***)
#                          Only MS                      11.1        44.2
#
#                                                     Top-10      Top-20
# Dataset       Ionization Method
# EA (Massbank) positive   MS + RT (Chain-graph)        70.1  79.1 (***)
#                          MS + RT (MetFrag 2.2)        69.5        77.1
#                          MS + RT (our)          72.9 (***)  80.7 (***)
#                          Only MS                      69.7        77.6
#               negative   MS + RT (Chain-graph)  72.4 (***)  81.8 (***)
#                          MS + RT (MetFrag 2.2)  73.6 (***)  84.4 (***)
#                          MS + RT (our)          73.8 (***)  83.6 (***)
#                          Only MS                      69.5        78.5
# CASMI 2016    positive   MS + RT (Chain-graph)  50.2 (***)  60.7 (***)
#                          MS + RT (MetFrag 2.2)        46.2        57.5
#                          MS + RT (our)          52.2 (***)  62.8 (***)
#                          Only MS                      47.0        58.3
#               negative   MS + RT (Chain-graph)  61.0 (***)  69.4 (***)
#                          MS + RT (MetFrag 2.2)        55.5  71.2 (***)
#                          MS + RT (our)           57.0 (**)  70.1 (***)
#                          Only MS                      55.3        68.0

# %% [markdown]
# #### Pairwise test for significant improvement
#
# **Table 4**: Is there a significant improvement of the row method over the column method?

# %%
res_global_sigf[1]

# print(res_global_sigf[1])
# Out:
# Method-2               Method-1 MS + RT (Chain-graph) MS + RT (MetFrag 2.2)  \
# 0         MS + RT (Chain-graph)                   n.s                   n.s
# 1         MS + RT (MetFrag 2.2)               4.3e-08                   n.s
# 2                 MS + RT (our)               8.7e-24               6.1e-08
# 3                       Only MS                   n.s                   n.s
#
# Method-2 MS + RT (our)  Only MS
# 0                  n.s  8.0e-26
# 1                  n.s  5.8e-38
# 2                  n.s  5.4e-39
# 3                  n.s      n.s

# %%
res_global_sigf[20]

# print(res_global_sigf[20])
# Out:
# Method-2               Method-1 MS + RT (Chain-graph) MS + RT (MetFrag 2.2)  \
# 0         MS + RT (Chain-graph)                   n.s               8.1e-04
# 1         MS + RT (MetFrag 2.2)                   n.s                   n.s
# 2                 MS + RT (our)               2.1e-13               1.5e-14
# 3                       Only MS                   n.s                   n.s
#
# Method-2 MS + RT (our)  Only MS
# 0                  n.s  4.3e-23
# 1                  n.s  4.3e-10
# 2                  n.s  1.5e-34
# 3                  n.s      n.s

# %%
print(table__alternative_methods_comparison(result_version, to_latex=True)[1][20])
# Out:
# \begin{tabular}{lllcccc}
# \toprule
#               Method-1 & MS + RT (Chain-graph) & MS + RT (MetFrag 2.2) & MS + RT (our) &  Only MS \\
# \midrule
#  MS + RT (Chain-graph) &                   n.s &               8.1e-04 &           n.s &  4.3e-23 \\
#  MS + RT (MetFrag 2.2) &                   n.s &                   n.s &           n.s &  4.3e-10 \\
#          MS + RT (our) &               2.1e-13 &               1.5e-14 &           n.s &  1.5e-34 \\
#                Only MS &                   n.s &                   n.s &           n.s &      n.s \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Comparison of MetFrag's and IOKR's used as MS2-Scorer
#
# In **Table 5** we compare the performance of the MS+RT score integration, when different MS2-Scorers, here MetFrag and IOKR, are used to process the MS2-spectra.

# %%
from msmsrt_scorer.experiments.figures_and_tables import table__MetFrag_vs_IOKR_comparison

table__MetFrag_vs_IOKR_comparison(result_version)
# Out:
#   \msms{}-Scorers   Method  Top-1  Top-5  Top-10  Top-20
# 0            IOKR  MS + RT   26.7   52.1    62.5    70.3
# 1            IOKR  Only MS   25.1   49.5    60.3    67.6
# 2         MetFrag  MS + RT   21.3   52.9    64.0    74.3
# 3         MetFrag  Only MS   16.7   49.5    60.4    70.6

# %%
print(table__MetFrag_vs_IOKR_comparison(result_version, to_latex=True))
# Out:
# \begin{tabular}{@{}llcccc@{}}
# \toprule
# \msms{}-Scorers &   Method &  Top-1 &  Top-5 &  Top-10 &  Top-20 \\
# \midrule
#            IOKR &  MS + RT &   26.7 &   52.1 &    62.5 &    70.3 \\
#            IOKR &  Only MS &   25.1 &   49.5 &    60.3 &    67.6 \\
#         MetFrag &  MS + RT &   21.3 &   52.9 &    64.0 &    74.3 \\
#         MetFrag &  Only MS &   16.7 &   49.5 &    60.4 &    70.6 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Comparison of different Candidate Set Definitions
#
# #### MetFrag
#
# Table 6.

# %%
from msmsrt_scorer.experiments.figures_and_tables import table__candidate_set_comparison

table__candidate_set_comparison(result_version, ms2scorer="MetFrag")
# Out:
#                                   Top-1       Top-5      Top-10      Top-20
# Candidate Set Method
# All           MS + RT (our)  14.6 (***)  44.0 (***)  54.6 (***)  66.5 (***)
#               Only MS              11.4        40.7        51.2        63.2
# Correct MF    MS + RT (our)  17.7 (***)  48.4 (***)  59.8 (***)  71.0 (***)
#               Only MS              13.1        46.0        56.9        68.7

# %%
print(table__candidate_set_comparison(result_version, ms2scorer="MetFrag", to_latex=True))
# Out:
# \begin{tabular}{lcccc}
# \toprule
# Candidate Set &         Method &       Top-1 &       Top-5 &      Top-10 &      Top-20 \\
# \midrule
#           All &  MS + RT (our) &  14.6 (***) &  44.0 (***) &  54.6 (***) &  66.5 (***) \\
#           All &        Only MS &        11.4 &        40.7 &        51.2 &        63.2 \\
#    Correct MF &  MS + RT (our) &  17.7 (***) &  48.4 (***) &  59.8 (***) &  71.0 (***) \\
#    Correct MF &        Only MS &        13.1 &        46.0 &        56.9 &        68.7 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# #### IOKR
#
# Not shown in the paper. Maybe we can put it into the supplementary material.

# %%
table__candidate_set_comparison(result_version, ms2scorer="IOKR")
# Out:
#                                   Top-1       Top-5      Top-10      Top-20
# Candidate Set Method
# All           MS + RT (our)  26.1 (***)  48.3 (***)  59.9 (***)  69.1 (***)
#               Only MS              24.4        46.0        58.4        65.5
# Correct MF    MS + RT (our)        30.2        52.3  66.2 (***)        74.7
#               Only MS              30.6        53.9        65.3        74.8

# %% [markdown]
# ## Supplementary Material
#
# ### Aggregated Metabolite Identification Performance of the different Edge-potential Functions
#
# Table S1.

# %%
from msmsrt_scorer.experiments.figures_and_tables import table__edgepotential_function_comparison

res_scores, res_p = table__edgepotential_function_comparison(result_version)

# print(table__edgepotential_function_comparison("..", to_latex=True, test="wilcoxon_twoside"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-95116679692e> in <module>
#       1 from msmsrt_scorer.experiments.figures_and_tables import table__edgepotential_function_comparison
#       2
# ----> 3 res_scores, res_p = table__edgepotential_function_comparison(result_version)
#       4
#       5 # print(table__edgepotential_function_comparison("..", to_latex=True, test="wilcoxon_twoside"))
#
# ~/Documents/doctoral/projects/rt_msms_score_integration_PUBLICATION/msmsrt_scorer/experiments/figures_and_tables.py in table__edgepotential_function_comparison(base_dir, to_latex, test, n_random_trees)
#     327                 margin_type=margin_type)
#     328
# --> 329             res.append(load_results(
#     330                 _idir, "MS + RT (our, %s)" % make_order_prob, max_n_ms2, n_samples=n_samples, method=eval_method,
#     331                 k_values_to_consider=k_values_to_consider, load_baseline=(i == 0))[0])
#
# ~/Documents/doctoral/projects/rt_msms_score_integration_PUBLICATION/msmsrt_scorer/experiments/plot_and_table_utils.py in load_results(idir, label_ms_rt, max_n_ms2, k_values_to_consider, method, return_percentage, label_only_ms, n_samples, load_baseline, load_ms_rt)
#      85     for s in range(n_samples):
#      86         fn = os.path.join(idir, TOPK(D_value=None, method=method, max_n_ms2=max_n_ms2, order_prob_k=None, sample_id=s))
# ---> 87         with gzip.open(fn) as file:
#      88             _topk = pickle.load(file)
#      89
#
# /usr/lib/python3.8/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      56     gz_mode = mode.replace("t", "")
#      57     if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      59     elif hasattr(filename, "read") or hasattr(filename, "write"):
#      60         binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# /usr/lib/python3.8/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     171             mode += 'b'
#     172         if fileobj is None:
# --> 173             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     174         if filename is None:
#     175             filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'LATEST/EA_Massbank/results__TFG__gridsearch/application/tree_method=random__n_trees=128__make_order_prob=stepfun__param_selection_measure=topk_auc__norm_scores=none__mtype=max/ion_mode=positive__participant=MetFrag_2.4.5__8afe4a14__max_n_cand=inf__sort_candidates_by_ms2_score=0/trainset=MEOH_AND_CASMI_JOINT__keep_test=0__est=ranksvm__mol_rep=substructure_count/topk_casmi__max_n_ms2=100__sample_id=000.pkl.gz'

# %%
res_scores
# Out:
#                          Method  Top-1  Top-5  Top-10  Top-20
# 0  MS + RT (our, hinge_sigmoid)   21.3   52.5    64.2    74.2
# 1        MS + RT (our, sigmoid)   21.2   52.6    63.9    73.9
# 2        MS + RT (our, stepfun)   20.3   52.2    63.8    74.2
# 3                       Only MS   16.7   49.5    60.4    70.6

# %%
res_p
# Out:
#                          Method  Top-1  Top-5 Top-10 Top-20
# 0  MS + RT (our, hinge_sigmoid)  (***)  (***)  (***)  (***)
# 1        MS + RT (our, sigmoid)  (***)  (***)  (***)  (***)
# 2        MS + RT (our, stepfun)  (***)  (***)  (***)  (***)

# %% [markdown]
# Table showing the significance of the improvement over the baseline (Only MS) determined using the two-sided Wilcoxon signed-rank test.
